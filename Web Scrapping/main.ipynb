# %%
# Importing library

import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
# Initialize an empty DataFrame
final = pd.DataFrame()

# %%
# Iterate through pages
for j in range(1, 501):  # Change range to scrape all pages (1 to 500)
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'
    }
    webpage = requests.get(url, headers=headers).text
    soup = BeautifulSoup(webpage, 'lxml')
    company = soup.find_all('div', class_="companyCardWrapper")
    
    # Create empty lists to store data
    name = []
    rating = []
    description = []
    highly_rated_for = []
    critically_rated_for = []
    reviews = []
    salaries = []
    interviews = []
    jobs = []
    benefits = []
    
    # Iterate over the companies
    for company in soup.find_all('div', class_='companyCardWrapper'):
        # Extract company name
        name.append(company.find('h2', class_="companyCardWrapper__companyName").text.strip())
        
        # Extract company rating if available
        rating_element = company.find('span', class_="companyCardWrapper__companyRatingValue")
        rating_value = rating_element.text.strip() if rating_element else np.nan
        rating.append(rating_value)
        
        # Extract company description
        description.append(company.find('div', class_="companyCardWrapper__interLinkingWrapper").text.strip())
        
        # Extract highly rated for and critically rated for if available
        ratings_element = company.find('span', class_="companyCardWrapper__ratingValues")
        if ratings_element:
            ratings = ratings_element.text.strip()
            ratings_split = ratings.split(',')
            if len(ratings_split) >= 2:
                highly_rated_for.append(ratings_split[0].strip())  # Assuming highly rated for is the first item
                critically_rated_for.append(ratings_split[1].strip())  # Assuming critically rated for is the second item
            else:
                highly_rated_for.append(np.nan)
                critically_rated_for.append(np.nan)
        else:
            highly_rated_for.append(np.nan)
            critically_rated_for.append(np.nan)
        
        # Extract reviews, salaries, interviews, jobs, benefits, and photos if available
        actions = company.find_all('span', class_='companyCardWrapper__ActionCount')
        reviews.append(actions[0].text.strip() if actions else np.nan)
        salaries.append(actions[1].text.strip() if len(actions) > 1 else np.nan)
        interviews.append(actions[2].text.strip() if len(actions) > 2 else np.nan)
        jobs.append(actions[3].text.strip() if len(actions) > 3 else np.nan)
        benefits.append(actions[4].text.strip() if len(actions) > 4 else np.nan)
    
    # Create a DataFrame from the collected data
    data = {
        'Name': name,
        'Rating': rating,
        'Description': description,
        'Highly Rated For': highly_rated_for,
        'Critically Rated For': critically_rated_for,
        'Reviews': reviews,
        'Salaries': salaries,
        'Interviews': interviews,
        'Jobs': jobs,
        'Benefits': benefits,
    }
    
    df = pd.DataFrame(data)
    
    # Append the DataFrame to the final DataFrame
    final = pd.concat([final, df], ignore_index=True)
    print("Data appended for page", j)

# Save the final DataFrame as a CSV file
final.to_csv('companies_data.csv', index=False)
print("CSV file created successfully.")
# Out:
# Data appended for page 1
# Data appended for page 2
# Data appended for page 3
# Data appended for page 4
# Data appended for page 5
# Data appended for page 6
# Data appended for page 7
# Data appended for page 8
# Data appended for page 9
# Data appended for page 10
# Data appended for page 11
# Data appended for page 12
# Data appended for page 13
# Data appended for page 14
# Data appended for page 15
# Data appended for page 16
# Data appended for page 17
# Data appended for page 18
# Data appended for page 19
# Data appended for page 20
# Data appended for page 21
# Data appended for page 22
# Data appended for page 23
# Data appended for page 24
# Data appended for page 25
# Data appended for page 26
# Data appended for page 27
# Data appended for page 28
# Data appended for page 29
# Data appended for page 30
# Data appended for page 31
# Data appended for page 32
# Data appended for page 33
# Data appended for page 34
# Data appended for page 35
# Data appended for page 36
# Data appended for page 37
# Data appended for page 38
# Data appended for page 39
# Data appended for page 40
# Data appended for page 41
# Data appended for page 42
# Data appended for page 43
# Data appended for page 44
# Data appended for page 45
# Data appended for page 46
# Data appended for page 47
# Data appended for page 48
# Data appended for page 49
# Data appended for page 50
# Data appended for page 51
# Data appended for page 52
# Data appended for page 53
# Data appended for page 54
# Data appended for page 55
# Data appended for page 56
# Data appended for page 57
# Data appended for page 58
# Data appended for page 59
# Data appended for page 60
# Data appended for page 61
# Data appended for page 62
# Data appended for page 63
# Data appended for page 64
# Data appended for page 65
# Data appended for page 66
# Data appended for page 67
# Data appended for page 68
# Data appended for page 69
# Data appended for page 70
# Data appended for page 71
# Data appended for page 72
# Data appended for page 73
# Data appended for page 74
# Data appended for page 75
# Data appended for page 76
# Data appended for page 77
# Data appended for page 78
# Data appended for page 79
# Data appended for page 80
# Data appended for page 81
# Data appended for page 82
# Data appended for page 83
# Data appended for page 84
# Data appended for page 85
# Data appended for page 86
# Data appended for page 87
# Data appended for page 88
# Data appended for page 89
# Data appended for page 90
# Data appended for page 91
# Data appended for page 92
# Data appended for page 93
# Data appended for page 94
# Data appended for page 95
# Data appended for page 96
# Data appended for page 97
# Data appended for page 98
# Data appended for page 99
# Data appended for page 100
# Data appended for page 101
# Data appended for page 102
# Data appended for page 103
# Data appended for page 104
# Data appended for page 105
# Data appended for page 106
# Data appended for page 107
# Data appended for page 108
# Data appended for page 109
# Data appended for page 110
# Data appended for page 111
# Data appended for page 112
# Data appended for page 113
# Data appended for page 114
# Data appended for page 115
# Data appended for page 116
# Data appended for page 117
# Data appended for page 118
# Data appended for page 119
# Data appended for page 120
# Data appended for page 121
# Data appended for page 122
# Data appended for page 123
# Data appended for page 124
# Data appended for page 125
# Data appended for page 126
# Data appended for page 127
# Data appended for page 128
# Data appended for page 129
# Data appended for page 130
# Data appended for page 131
# Data appended for page 132
# Data appended for page 133
# Data appended for page 134
# Data appended for page 135
# Data appended for page 136
# Data appended for page 137
# Data appended for page 138
# Data appended for page 139
# Data appended for page 140
# Data appended for page 141
# Data appended for page 142
# Data appended for page 143
# Data appended for page 144
# Data appended for page 145
# Data appended for page 146
# Data appended for page 147
# Data appended for page 148
# Data appended for page 149
# Data appended for page 150
# Data appended for page 151
# Data appended for page 152
# Data appended for page 153
# Data appended for page 154
# Data appended for page 155
# Data appended for page 156
# Data appended for page 157
# Data appended for page 158
# Data appended for page 159
# Data appended for page 160
# Data appended for page 161
# Data appended for page 162
# Data appended for page 163
# Data appended for page 164
# Data appended for page 165
# Data appended for page 166
# Data appended for page 167
# Data appended for page 168
# Data appended for page 169
# Data appended for page 170
# Data appended for page 171
# Data appended for page 172
# Data appended for page 173
# Data appended for page 174
# Data appended for page 175
# Data appended for page 176
# Data appended for page 177
# Data appended for page 178
# Data appended for page 179
# Data appended for page 180
# Data appended for page 181
# Data appended for page 182
# Data appended for page 183
# Data appended for page 184
# Data appended for page 185
# Data appended for page 186
# Data appended for page 187
# Data appended for page 188
# Data appended for page 189
# Data appended for page 190
# Data appended for page 191
# Data appended for page 192
# Data appended for page 193
# Data appended for page 194
# Data appended for page 195
# Data appended for page 196
# Data appended for page 197
# Data appended for page 198
# Data appended for page 199
# Data appended for page 200
# Data appended for page 201
# Data appended for page 202
# Data appended for page 203
# Data appended for page 204
# Data appended for page 205
# Data appended for page 206
# Data appended for page 207
# Data appended for page 208
# Data appended for page 209
# Data appended for page 210
# Data appended for page 211
# Data appended for page 212
# Data appended for page 213
# Data appended for page 214
# Data appended for page 215
# Data appended for page 216
# Data appended for page 217
# Data appended for page 218
# Data appended for page 219
# Data appended for page 220
# Data appended for page 221
# Data appended for page 222
# Data appended for page 223
# Data appended for page 224
# Data appended for page 225
# Data appended for page 226
# Data appended for page 227
# Data appended for page 228
# Data appended for page 229
# Data appended for page 230
# Data appended for page 231
# Data appended for page 232
# Data appended for page 233
# Data appended for page 234
# Data appended for page 235
# Data appended for page 236
# Data appended for page 237
# Data appended for page 238
# Data appended for page 239
# Data appended for page 240
# Data appended for page 241
# Data appended for page 242
# Data appended for page 243
# Data appended for page 244
# Data appended for page 245
# Data appended for page 246
# Data appended for page 247
# Data appended for page 248
# Data appended for page 249
# Data appended for page 250
# Data appended for page 251
# Data appended for page 252
# Data appended for page 253
# Data appended for page 254
# Data appended for page 255
# Data appended for page 256
# Data appended for page 257
# Data appended for page 258
# Data appended for page 259
# Data appended for page 260
# Data appended for page 261
# Data appended for page 262
# Data appended for page 263
# Data appended for page 264
# Data appended for page 265
# Data appended for page 266
# Data appended for page 267
# Data appended for page 268
# Data appended for page 269
# Data appended for page 270
# Data appended for page 271
# Data appended for page 272
# Data appended for page 273
# Data appended for page 274
# Data appended for page 275
# Data appended for page 276
# Data appended for page 277
# Data appended for page 278
# Data appended for page 279
# Data appended for page 280
# Data appended for page 281
# Data appended for page 282
# Data appended for page 283
# Data appended for page 284
# Data appended for page 285
# Data appended for page 286
# Data appended for page 287
# Data appended for page 288
# Data appended for page 289
# Data appended for page 290
# Data appended for page 291
# Data appended for page 292
# Data appended for page 293
# Data appended for page 294
# Data appended for page 295
# Data appended for page 296
# Data appended for page 297
# Data appended for page 298
# Data appended for page 299
# Data appended for page 300
# Data appended for page 301
# Data appended for page 302
# Data appended for page 303
# Data appended for page 304
# Data appended for page 305
# Data appended for page 306
# Data appended for page 307
# Data appended for page 308
# Data appended for page 309
# Data appended for page 310
# Data appended for page 311
# Data appended for page 312
# Data appended for page 313
# Data appended for page 314
# Data appended for page 315
# Data appended for page 316
# Data appended for page 317
# Data appended for page 318
# Data appended for page 319
# Data appended for page 320
# Data appended for page 321
# Data appended for page 322
# Data appended for page 323
# Data appended for page 324
# Data appended for page 325
# Data appended for page 326
# Data appended for page 327
# Data appended for page 328
# Data appended for page 329
# Data appended for page 330
# Data appended for page 331
# Data appended for page 332
# Data appended for page 333
# Data appended for page 334
# Data appended for page 335
# Data appended for page 336
# Data appended for page 337
# Data appended for page 338
# Data appended for page 339
# Data appended for page 340
# Data appended for page 341
# Data appended for page 342
# Data appended for page 343
# Data appended for page 344
# Data appended for page 345
# Data appended for page 346
# Data appended for page 347
# Data appended for page 348
# Data appended for page 349
# Data appended for page 350
# Data appended for page 351
# Data appended for page 352
# Data appended for page 353
# Data appended for page 354
# Data appended for page 355
# Data appended for page 356
# Data appended for page 357
# Data appended for page 358
# Data appended for page 359
# Data appended for page 360
# Data appended for page 361
# Data appended for page 362
# Data appended for page 363
# Data appended for page 364
# Data appended for page 365
# Data appended for page 366
# Data appended for page 367
# Data appended for page 368
# Data appended for page 369
# Data appended for page 370
# Data appended for page 371
# Data appended for page 372
# Data appended for page 373
# Data appended for page 374
# Data appended for page 375
# Data appended for page 376
# Data appended for page 377
# Data appended for page 378
# Data appended for page 379
# Data appended for page 380
# Data appended for page 381
# Data appended for page 382
# Data appended for page 383
# Data appended for page 384
# Data appended for page 385
# Data appended for page 386
# Data appended for page 387
# Data appended for page 388
# Data appended for page 389
# Data appended for page 390
# Data appended for page 391
# Data appended for page 392
# Data appended for page 393
# Data appended for page 394
# Data appended for page 395
# Data appended for page 396
# Data appended for page 397
# Data appended for page 398
# Data appended for page 399
# Data appended for page 400
# Data appended for page 401
# Data appended for page 402
# Data appended for page 403
# Data appended for page 404
# Data appended for page 405
# Data appended for page 406
# Data appended for page 407
# Data appended for page 408
# Data appended for page 409
# Data appended for page 410
# Data appended for page 411
# Data appended for page 412
# Data appended for page 413
# Data appended for page 414
# Data appended for page 415
# Data appended for page 416
# Data appended for page 417
# Data appended for page 418
# Data appended for page 419
# Data appended for page 420
# Data appended for page 421
# Data appended for page 422
# Data appended for page 423
# Data appended for page 424
# Data appended for page 425
# Data appended for page 426
# Data appended for page 427
# Data appended for page 428
# Data appended for page 429
# Data appended for page 430
# Data appended for page 431
# Data appended for page 432
# Data appended for page 433
# Data appended for page 434
# Data appended for page 435
# Data appended for page 436
# Data appended for page 437
# Data appended for page 438
# Data appended for page 439
# Data appended for page 440
# Data appended for page 441
# Data appended for page 442
# Data appended for page 443
# Data appended for page 444
# Data appended for page 445
# Data appended for page 446
# Data appended for page 447
# Data appended for page 448
# Data appended for page 449
# Data appended for page 450
# Data appended for page 451
# Data appended for page 452
# Data appended for page 453
# Data appended for page 454
# Data appended for page 455
# Data appended for page 456
# Data appended for page 457
# Data appended for page 458
# Data appended for page 459
# Data appended for page 460
# Data appended for page 461
# Data appended for page 462
# Data appended for page 463
# Data appended for page 464
# Data appended for page 465
# Data appended for page 466
# Data appended for page 467
# Data appended for page 468
# Data appended for page 469
# Data appended for page 470
# Data appended for page 471
# Data appended for page 472
# Data appended for page 473
# Data appended for page 474
# Data appended for page 475
# Data appended for page 476
# Data appended for page 477
# Data appended for page 478
# Data appended for page 479
# Data appended for page 480
# Data appended for page 481
# Data appended for page 482
# Data appended for page 483
# Data appended for page 484
# Data appended for page 485
# Data appended for page 486
# Data appended for page 487
# Data appended for page 488
# Data appended for page 489
# Data appended for page 490
# Data appended for page 491
# Data appended for page 492
# Data appended for page 493
# Data appended for page 494
# Data appended for page 495
# Data appended for page 496
# Data appended for page 497
# Data appended for page 498
# Data appended for page 499
# Data appended for page 500
# CSV file created successfully.

# %%
final.shape
# Out:
# (10000, 10)

# %% [markdown]
# # Explanation of the column

# %%
# Name --> Name of the company
# Rating --> Rating of the company
# Description --> Explanation in short
# Highly Rated for --> Positive part about the company
# Critically Rated for --> Negative part about the compnay
# Reviews --> Number of Reviews Given by employees
# Salaries --> Salaries for different post given by employees
# Interviews --> Number of Interview Question avaliable 
# Jobs --> Different Types of Jobs
# Benefits -> Different Types of Benefits

# %%
final.sample(10)
# Out:
#                                 Name Rating  \
# 4648                     V2Solutions    3.7
# 6608           Armed Forces Tribunal    4.8
# 5715                  Carnival Group    4.0
# 3648  L&T Water & Effluent Treatment    4.4
# 1328                         Hitachi    4.1
# 1565                            CARE    4.3
# 8475             Isgec Hitachi Zosen    3.5
# 7427                          DNV GL    4.3
# 8249                   Synnat Pharma    4.4
# 8847         Sigma Corporation India    4.3
#
#                                             Description  \
# 4648  IT Services & Consulting | 501-1k Employees | ...
# 6608  Government | 11-50 Employees | 17 years old | ...
# 5715  Media & Entertainment | 51-200 Employees | Con...
# 3648  Engineering & Construction | 5k-10k Employees ...
# 1328  Industrial Machinery | 10k-50k Employees | For...
# 1565  Non-Profit | 1k-5k Employees | 74 years old | ...
# 8475  Industrial Machinery | 201-500 Employees | 12 ...
# 7427  IT Services & Consulting | 1k-5k Employees | 1...
# 8249  1-10 Employees | 13 years old | Secunderabad +...
# 8847  Auto Components | 201-500 Employees | 60 years...
#
#             Highly Rated For          Critically Rated For Reviews Salaries  \
# 4648  Promotions / Appraisal                  Job Security     167     1.1k
# 6608         Company Culture                  Job Security     114      397
# 5715       Work Life Balance               Company Culture     133      308
# 3648            Job Security  Skill Development / Learning     210      185
# 1328         Company Culture                  Job Security     557     3.8k
# 1565         Company Culture  Skill Development / Learning     476     1.2k
# 8475       Salary & Benefits                  Job Security      92      512
# 7427         Company Culture             Work Life Balance     100      539
# 8249       Work Life Balance  Skill Development / Learning      91      160
# 8847            Job Security             Work Life Balance      84      574
#
#      Interviews Jobs Benefits
# 4648         12   --       25
# 6608         --   --       22
# 5715         --   --       19
# 3648          8   --      146
# 1328         59  275       66
# 1565         36   --       84
# 8475          6   --        8
# 7427          6   --       11
# 8249          2   --        4
# 8847          5   --       12

# %%
final.isnull().sum()
# Out:
# Name                       0
# Rating                     3
# Description                0
# Highly Rated For        1571
# Critically Rated For    1571
# Reviews                    0
# Salaries                   0
# Interviews                 0
# Jobs                       0
# Benefits                   0
# dtype: int64

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  10000 non-null  object
#  1   Rating                9997 non-null   object
#  2   Description           10000 non-null  object
#  3   Highly Rated For      8429 non-null   object
#  4   Critically Rated For  8429 non-null   object
#  5   Reviews               10000 non-null  object
#  6   Salaries              10000 non-null  object
#  7   Interviews            10000 non-null  object
#  8   Jobs                  10000 non-null  object
#  9   Benefits              10000 non-null  object
# dtypes: object(10)
# memory usage: 781.4+ KB

# %%
final.duplicated().sum()
# Out:
# 121
